# %%
1+2 #ctrl+enter运行，每写一部分代码，可以运行看下结果，适合教学。
#相当于把jupyter网页内嵌进来，由服务器托管。
# Out:
# 3

# %%
a=5

# %%
a #不同代码块的变量，也可以使用（但要先按ctrl+enter）
# Out:
# 5

# %% [markdown]
# 这是个注释：Markdown添加注释。 重启内核会造成内存的变量丢失。
#
# jupyter常驻内存（文件标绿点），造成卡顿时，选择不用的jupyter，右键关闭内核，释放内存。
#
# 注：jupyter只能导入py文件，不能导入别的jupyter文件。 因此如果一个代码需要用在多个jupyter文件上，可以写到py文件里再导入。
#
# 最后在服务器上运行py文件，需要右键把jupyter文件转化成py文件。

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([0.5,1,2,4],[0.25,1,4,16]) #两个列表，前者是x坐标，后者是y坐标
plt.show() #展示图像

# %% [markdown]
# # 7.2 折线的颜色和形状设置

# %%
x = range(1,8) # x轴的位置
y = [17, 17, 18, 15, 11, 11, 13]
# 传入x和y, 通过plot画折线图
plt.plot(x, y, color='red',alpha=0.5,linestyle='--',linewidth=3)
plt.show()
'''基础属性设置
color='red' : 折线的颜色
alpha=0.5 : 折线的透明度(0-1)
linestyle='--' : 折线的样式
linewidth=3 : 折线的宽度—粗细
'''
'''线的样式
- 实线(solid)
-- 短线(dashed)
-. 短点相间线(dashdot)
: 虚点线(dotted)
'''
# Out:
# '线的样式\n- 实线(solid)\n-- 短线(dashed)\n-. 短点相间线(dashdot)\n: 虚点线(dotted)\n'

# %% [markdown]
# # 7.4设置的图片的大小和保存

# %%
import random
x=range(2,26,2)#x轴的位置
y=[random.randint(15,30) for i in x]
#设置图片的大小
'''
figsize:指定figure的宽和高，单位为英寸；
dpi参数指定绘图对象的分辨率，即每英寸多少个像素，缺省值为80，1英寸等于2.5cm,A4纸是21*30cm的纸张

figure是画板，axes是图纸，一次画图只能创建一个画板（一个figure），重复创建会覆盖
'''
#设置画布对象，figsize中对应的单位是英寸，dpi是每英寸有多少像素点
plt.figure(figsize=(20,8),dpi=80)
plt.plot(x,y) # 传入x和y, 通过plot画图
#plt.show()
# 保存(注意： 要放在绘制的下面,并且plt.show()会释放figure资源，如果在显示图像之后保存图片将只能保存空图片。)
plt.savefig('./t1.png')
#图片的格式也可以保存为svg这种矢量图格式，这种矢量图放在网页中放大后不会有锯齿
# plt.savefig('./t1.svg')

# %% [markdown]
# # 7.5 绘制x轴和y轴的刻度

# %%
#关注刻度位置和刻度标签，若标签过长，则可以旋转
# plt.xticks(ticks=None, labels=None, rotation=0, fontsize=None, color=None)
# 1.ticks：刻度的位置（必须是数字列表，代表在 x 轴的哪个坐标上画刻度）
# 2.labels：刻度显示的文字（可以是任意字符串列表，和ticks一一对应


x = range(2,26,2) # x轴的位置
y = [random.randint(15, 30) for i in x] #列表生成式：[ 最终要放进列表的东西   for   临时变量   in   可迭代对象 ]
plt.figure(figsize=(20,8),dpi=80)
# 设置x轴的刻度
# plt.xticks(x)
# plt.xticks(range(1,25))
# 设置y轴的刻度
# plt.yticks(y)  写法1：直接用y作为刻度，问题：y是随机数，刻度会不均匀，比如15,17,18,20... 不美观
# plt.yticks(range(min(y),max(y)+1)) 写法2：用y的最小值到最大值的所有整数作为刻度，效果：刻度均匀，从最低温度到最高温度，每个整数一个刻度
# 构造x轴刻度标签
x_ticks_label = [f"{i}:00" for i in x]
#rotation = 45 让字旋转45度
plt.xticks(x,x_ticks_label,rotation = 45) #（刻度及个数，刻度内容，旋转角度）

# plt.xticks()的三个核心参数：
# 第一个参数x：刻度的位置（必须和数据点的 x 坐标对应）
# 第二个参数x_ticks_label：刻度显示的文字（可以是任意字符串）
# rotation=45：让刻度文字旋转 45 度，避免文字重叠挤在一起

# 设置y轴的刻度标签
y_ticks_label = ["{}℃".format(i) for i in range(min(y),max(y)+1)]
plt.yticks(range(min(y),max(y)+1),y_ticks_label)
# 绘图
plt.plot(x,y)
plt.show()

# %% [markdown]
# # 7.8 一图多个坐标系子图

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(1, 100) #划分子图
fig,axes=plt.subplots(2,2)
ax1=axes[0,0]
ax2=axes[0,1]
ax3=axes[1,0]
ax4=axes[1,1]

fig=plt.figure(figsize=(20,10),dpi=80) #作图 1
ax1.plot(x, x) # 作 图 2
ax2.plot(x,-x) #作图 3
ax3.plot(x, x**2)
# ax3.grid(color='r', linestyle='--', linewidth=1,alpha=0.3) #作图 4
ax4.plot(x, np.log(x))
plt.show()

# add_subplot 方法----给 figure 新增子图
x = np.arange(1,100)
#新建figure对象
fig=plt.figure(figsize=(20,10),dpi=80) #新建子图 1
ax1=fig.add_subplot(2,2,1)
ax1.plot(x, x)
#新建子图2
ax3=fig.add_subplot(2,2,2)
ax3.plot(x, x**2)
ax3.grid(color='r', linestyle='--', linewidth=1,alpha=0.3)
# 新 建 子 图3
ax4=fig.add_subplot(2,2,3)
ax4.plot(x, np.log(x))
plt.show()

# %% [markdown]
# # 7.7 一图多线

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# ===================== 解决中文显示（必加这3行）=====================
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用黑体显示中文
plt.rcParams['axes.unicode_minus'] = False    # 正常显示负号
# ====================================================================

epochs = np.arange(1, 11)
train_loss = [0.9, 0.72, 0.58, 0.45, 0.38, 0.32, 0.28, 0.25, 0.22, 0.20]
val_loss = [0.95, 0.8, 0.65, 0.55, 0.48, 0.42, 0.38, 0.35, 0.33, 0.32]

plt.figure(figsize=(10, 6))

# 第1步：给每条线加 label 参数
plt.plot(epochs, train_loss, color='red', label='训练集 Loss')
plt.plot(epochs, val_loss, color='blue', label='验证集 Loss')

# 第2步：调用 plt.legend() 显示图例
plt.legend() #画多线图，一定要加上图例。

plt.title('训练与验证 Loss 曲线')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# # 7.9 绘制条形图

# %%
from matplotlib import font_manager
my_font = font_manager.FontProperties(fname=r'C:\Windows\Fonts\STSONG.TTF',size=16)
a = ['流浪地球','疯狂的外星人','飞驰人生','大黄蜂','熊出没·原始时代','新喜剧之王']
b = [38.13,19.85,14.89,11.36,6.47,5.93]
plt.figure(figsize=(20,8),dpi=80)
# 绘制条形图的方法
'''
width=0.3 条形的宽度
'''
rects = plt.bar(range(len(a)),b,width=0.3,color='r')
plt.xticks(range(len(a)),a,fontproperties=my_font,rotation=45)
# 在条形图上加标注(水平居中)
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height+0.3, str(height),ha="center")
plt.show()

# %% [markdown]
# # 7.10 直方图

# %%
'''
现有250部电影的时长，希望统计出这些电影时长的分布状态(比如时长为100分钟到120分钟电影
的数量，出现的频率)等信息，你应该如何呈现这些数据？
'''
# 1）准备数据
time = [131, 98, 125, 131, 124, 139, 131, 117, 128, 108, 135, 138, 131, 102,
107, 114,
119, 128, 121, 142, 127, 130, 124, 101, 110, 116, 117, 110, 128, 128, 115,
99,
136, 126, 134, 95, 138, 117, 111,78, 132, 124, 113, 150, 110, 117, 86,
95, 144,
105, 126, 130,126, 130, 126, 116, 123, 106, 112, 138, 123, 86, 101, 99, 136,123,
117, 119, 105, 137, 123, 128, 125, 104, 109, 134, 125, 127,105, 120, 107, 129,
116,
108, 132, 103, 136, 118, 102, 120, 114,105, 115, 132, 145, 119, 121, 112, 139,
125,
138, 109, 132, 134,156, 106, 117, 127, 144, 139, 139, 119, 140, 83, 110,
102,123,
107, 143, 115, 136, 118, 139, 123, 112, 118, 125, 109, 119, 133,112, 114, 122,
109,
106, 123, 116, 131, 127, 115, 118, 112, 135,115, 146, 137, 116, 103,
144, 83, 123,
111, 110, 111, 100, 154,136, 100, 118, 119, 133, 134, 106, 129, 126,
110, 111, 109,
141,120, 117, 106, 149, 122, 122, 110, 118, 127, 121, 114, 125, 126,114, 140, 103,
130, 141, 117, 106, 114, 121, 114, 133, 137,
92,121,
112, 146, 97, 137,
105, 98,
117, 112, 81, 97, 139, 113,134, 106, 144, 110, 137, 137, 111, 104, 117,
100, 111,
101, 110,105, 129, 137, 112, 120, 113, 133, 112,
83,
94,
146, 133,
101,131, 116,
111, 84, 137, 115, 122, 106, 144, 109, 123, 116, 111,111, 133, 150]
from matplotlib import font_manager
from matplotlib import pyplot as plt
my_font = font_manager.FontProperties(fname=r'C:\Windows\Fonts\STSONG.TTF',size=18) 
# 2）创建画布
plt.figure(figsize=(20, 8), dpi=100) # 3）绘制直方图
# 设置组距
distance = 2
# 计算组数
group_num = int((max(time)- min(time)) / distance) # 绘制直方图
plt.hist(time, bins=group_num)
# 修改x轴刻度显示
plt.xticks(range(min(time), max(time))[::2])
# 添加网格显示
plt.grid(linestyle="--", alpha=0.5)
#添 加 x, y 轴 描 述 信 息
plt.xlabel("电影时长大小",fontproperties=my_font)
plt.ylabel("电影的数据量",fontproperties=my_font)
# 4）显示图像
plt.show()
